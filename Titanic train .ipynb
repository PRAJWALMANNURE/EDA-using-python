# %% [markdown]
# # EXPLORATORY DATA ANALYSIS
# What is Exploratory Data Analysis (EDA)?
# Exploratory Data Analysis (EDA) is used on the one hand to answer questions, test business assumptions, generate hypotheses for further analysis. On the other hand, you can also use it to prepare the data for modeling. The thing that these two probably have in common is a good knowledge of your data to either get the answers that you need or to develop an intuition for interpreting the results of future modeling.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("D:/Datascience/titanic/train.csv")

# %%
data.head() # shows the top 5 rows the of the dataset
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail() # gives the bottom 5 last rows of the dataset
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.describe(include="all") 
# includes all the columns, otherwise it only consider numerical columns.
# Out:
#         PassengerId    Survived      Pclass                    Name   Sex  \
# count    891.000000  891.000000  891.000000                     891   891
# unique          NaN         NaN         NaN                     891     2
# top             NaN         NaN         NaN  Hart, Miss. Eva Miriam  male
# freq            NaN         NaN         NaN                       1   577
# mean     446.000000    0.383838    2.308642                     NaN   NaN
# std      257.353842    0.486592    0.836071                     NaN   NaN
# min        1.000000    0.000000    1.000000                     NaN   NaN
# 25%      223.500000    0.000000    2.000000                     NaN   NaN
# 50%      446.000000    0.000000    3.000000                     NaN   NaN
# 75%      668.500000    1.000000    3.000000                     NaN   NaN
# max      891.000000    1.000000    3.000000                     NaN   NaN
#
#                Age       SibSp       Parch Ticket        Fare        Cabin  \
# ...

# %% [markdown]
# # describe the data types of all the features

# %%
data.shape  #shape of the dataset, i.e num of columns and rows.
# Out:
# (891, 12)

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # Checking the unique values in particular column

# %%
data['Survived'].unique() # shows all the unique values
# Out:
# array([0, 1], dtype=int64)

# %%
data['Survived'].nunique() # gives total number of unique values
# Out:
# 2

# %%
data['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data['Sex'].nunique()
# Out:
# 2

# %%
data.Sex.unique #without brackets it shows the list of unique values
# Out:
# <bound method Series.unique of 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object>

# %% [markdown]
# # Plot for understanding the target variable

# %%
sns.catplot(x='Survived', kind="count", data=data)

# %%
data.Survived.value_counts(1)*100  #percentage value counts
# Out:
# 0    61.616162
# 1    38.383838
# Name: Survived, dtype: float64

# %% [markdown]
# # changing the column names

# %% [markdown]
# for commenting the code shortcut is (cntrl+/)

# %%
# data=data.rename(columns={'Survived':'output'})

# %% [markdown]
# # Reading all the column names

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
data.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
data.Parch.unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %%
data.Ticket.nunique()
# Out:
# 681

# %%
sns.heatmap(data.isnull(), yticklabels=False, cbar=False, cmap='viridis')
#shows the columns which are having null values.

# %% [markdown]
# # finding the null values

# %%
total = data.isnull().sum().sort_values(ascending=False)
print(total)
# Out:
# Cabin          687
# Age            177
# Embarked         2
# Fare             0
# Ticket           0
# Parch            0
# SibSp            0
# Sex              0
# Name             0
# Pclass           0
# Survived         0
# PassengerId      0
# dtype: int64

# %% [markdown]
# # detecting the outliers

# %%
plt.figure(figsize=(5,5))
plt.title("boxplot",fontsize=20)
data.boxplot(vert=0)

# %% [markdown]
# # Checking the distribution of features

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000017CE46E2BB0>,
# ...
#       dtype=object)

# %%
sns.pairplot(data,hue="Survived")
# Out:
# C:\Users\PJ\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Finding the correlation of features

# %%
plt.figure(figsize=(12,7)) 
sns.heatmap(data.corr(), annot=True, cmap='Blues')
# heatmap which shows the correlation plot of variables with correlation coeffiecient
#Darker the blue higher is the positive correlation and vice versa.
#here we can see that fare and pclass are having strong negative correlation
